# %% [markdown]
# # Weather Station Clustering

# %% [markdown]
# ### About Dataset
#
# Environment Canada
# Monthly Values for July - 2015
#
# Legend
# Stn_Name::::	Station Name
# Lat	    ::::	Latitude (North + , degrees)
# Long	::::	Longitude (West - , degrees)
# Prov	::::	Province
# Tm	    ::::	Mean Temperature (Â°C)
# DwTm	::::	Days without Valid Mean Temperature
# D	    ::::	Mean Temperature difference from Normal (1981-2010) (Â°C)
# Tx	    ::::	Highest Monthly Maximum Temperature (Â°C)
# DwTx	::::	Days without Valid Maximum Temperature
# Tn	    ::::	Lowest Monthly Minimum Temperature (Â°C)
# DwTn	::::	Days without Valid Minimum Temperature
# S	    ::::	Snowfall (cm)
# DwS	    ::::	Days without Valid Snowfall
# S%N	    ::::	Percent of Normal (1981-2010) Snowfall
# P	    ::::	Total Precipitation (mm)
# DwP	    ::::	Days without Valid Precipitation
# P%N	    ::::	Percent of Normal (1981-2010) Precipitation
# S_G  	::::	Snow on the ground at the end of the month (cm)
# Pd	    ::::	Number of days with Precipitation 1.0 mm or more
# BS	    ::::	Bright Sunshine (hours)
# DwBS	::::	Days without Valid Bright Sunshine
# BS%  	::::	Percent of Normal (1981-2010) Bright Sunshine
# HDD 	::::	Degree Days below 18 Â°C
# CDD	    ::::	Degree Days above 18 Â°C
# Stn_No	::::	Climate station identifier (first 3 digits indicate   drainage basin, last 4 characters are for sorting alphabetically).
# NA	    ::::	Not Available

# %% [markdown]
# ### 1-Download data into your Data Scientist Workbench

# %%
# !wget -O weather-stations20140101-20141231.csv https://ibm.box.com/shared/static/mv6g5p1wpmpvzoz6e5zgo47t44q8dvm0.csv
# Out:
# --2017-05-07 23:33:14--  https://ibm.box.com/shared/static/mv6g5p1wpmpvzoz6e5zgo47t44q8dvm0.csv
# Resolving ibm.box.com (ibm.box.com)... 107.152.24.197, 107.152.25.197
# Connecting to ibm.box.com (ibm.box.com)|107.152.24.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/shared/static/mv6g5p1wpmpvzoz6e5zgo47t44q8dvm0.csv [following]
# --2017-05-07 23:33:14--  https://ibm.ent.box.com/shared/static/mv6g5p1wpmpvzoz6e5zgo47t44q8dvm0.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 107.152.27.211
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|107.152.27.211|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/KhdN-KRJDr67fgdJsW1gB1XtMwXl7f9SRx2UGakIvWQEdfMav19fNyQx_Qd1lBohsVOWRdlHaifnnu5o0DM6TOcMwLeCmH-EiuCuivVsHCq6iXixNoA1-3Vwwm2-sj3GdWcQlVNOIefXpcxG_IL06SxIZ-Zvdgcmys7f6fAnUfCVp022SldsadHatR868I-mr_am5UnXfAZZuxTDeG7Bg9PF86Ex2Ajd773JiKJH9hUV8fYotSqICVjzs3zRAudIX9lgFlVVYlq0DbkmNGhzr7eZ50mTeL2aUEX7FoSSAREq3POBzneZbPbsexXyVyv1_SVoonuPgghfqkZ3dbJjXbri4WE5o0EZ5eSYD0WewysuHefdsDOWbcALJ6hN3PKnT-JhY0i28H_dGrhgsI7N2KJdEFeycHtkJx7EQWpugQK8jFpt6QIsd2JHIoiQPvn3uGHkDQcrc-Uj8FH_2vB79biyk0Nzg3vVwVS90iAI9VS4yx0gzqnmtFFI7o0faDzXeYxXsrvkzDG_h8kIvEF0CRM_zPpIsva4Aobbgpc9dKVsjXRRzJP1TMt007C3KZjvsqy4BDzgudcZAUEa93jXbawZY77-sMpf9kv_tbdjHYkRWOEjkyr7C7WbdqzJKo7yp6oTpFp-X94RDrB_30Tu7s4-ZEaabYJO2tDZfsHwyDQAftxbLoNrSHOFtmMhp4se5KSApv7Kh2fI3yBH8-4_fuZmihu6XFXnpZlAaV48xZv2W22E1dy9gwN1oWzaX4wvScmX2MK91_MACbGNW21InuA9mmA1F15uUWfyRmtWnQVaRD-5PQVwutf-CsRunU0h-8GvN_3MvPTIRC3hjxCTcwP8zykUyMmAkcXc9e7zQqLKU1WqE5ZRRyojIvFuzX9QGex43R1f4MgqmtxxsZD9LJ-iQWkfZa_VcEyCCBU2wyn0zWo7II6BY63TCHofsZZ48IvbmrERZyHHbsg2UQZqBKQj9decyztdlAALGizAB5QhwNaHLvFel5_nSoIDSlzjOKX7emNmMwL78K3UuynQTUu9sKF1jkttPucvxVUFZd2GszAwwRh66K07GoFhdkMazCCV7p78I9BLg84kNUmRPZSRs6vS1A143BAsXqqfam191bOQzfincVIf1EvcVYzDX9Eb-am3BPQSPojmiKjbWnLxfTb1D9KsSEp7q4dSUoeo0eNJlStBRwhbJVRJXdSZknih2uF2dMZwdfNTA_2q5XTjUSd3VbGGDQ../download [following]
# --2017-05-07 23:33:15--  https://public.boxcloud.com/d/1/KhdN-KRJDr67fgdJsW1gB1XtMwXl7f9SRx2UGakIvWQEdfMav19fNyQx_Qd1lBohsVOWRdlHaifnnu5o0DM6TOcMwLeCmH-EiuCuivVsHCq6iXixNoA1-3Vwwm2-sj3GdWcQlVNOIefXpcxG_IL06SxIZ-Zvdgcmys7f6fAnUfCVp022SldsadHatR868I-mr_am5UnXfAZZuxTDeG7Bg9PF86Ex2Ajd773JiKJH9hUV8fYotSqICVjzs3zRAudIX9lgFlVVYlq0DbkmNGhzr7eZ50mTeL2aUEX7FoSSAREq3POBzneZbPbsexXyVyv1_SVoonuPgghfqkZ3dbJjXbri4WE5o0EZ5eSYD0WewysuHefdsDOWbcALJ6hN3PKnT-JhY0i28H_dGrhgsI7N2KJdEFeycHtkJx7EQWpugQK8jFpt6QIsd2JHIoiQPvn3uGHkDQcrc-Uj8FH_2vB79biyk0Nzg3vVwVS90iAI9VS4yx0gzqnmtFFI7o0faDzXeYxXsrvkzDG_h8kIvEF0CRM_zPpIsva4Aobbgpc9dKVsjXRRzJP1TMt007C3KZjvsqy4BDzgudcZAUEa93jXbawZY77-sMpf9kv_tbdjHYkRWOEjkyr7C7WbdqzJKo7yp6oTpFp-X94RDrB_30Tu7s4-ZEaabYJO2tDZfsHwyDQAftxbLoNrSHOFtmMhp4se5KSApv7Kh2fI3yBH8-4_fuZmihu6XFXnpZlAaV48xZv2W22E1dy9gwN1oWzaX4wvScmX2MK91_MACbGNW21InuA9mmA1F15uUWfyRmtWnQVaRD-5PQVwutf-CsRunU0h-8GvN_3MvPTIRC3hjxCTcwP8zykUyMmAkcXc9e7zQqLKU1WqE5ZRRyojIvFuzX9QGex43R1f4MgqmtxxsZD9LJ-iQWkfZa_VcEyCCBU2wyn0zWo7II6BY63TCHofsZZ48IvbmrERZyHHbsg2UQZqBKQj9decyztdlAALGizAB5QhwNaHLvFel5_nSoIDSlzjOKX7emNmMwL78K3UuynQTUu9sKF1jkttPucvxVUFZd2GszAwwRh66K07GoFhdkMazCCV7p78I9BLg84kNUmRPZSRs6vS1A143BAsXqqfam191bOQzfincVIf1EvcVYzDX9Eb-am3BPQSPojmiKjbWnLxfTb1D9KsSEp7q4dSUoeo0eNJlStBRwhbJVRJXdSZknih2uF2dMZwdfNTA_2q5XTjUSd3VbGGDQ../download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.27.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.27.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 129821 (127K) [text/csv]
# Saving to: ‘weather-stations20140101-20141231.csv’
#
# 100%[======================================>] 129,821      646KB/s   in 0.2s
#
# 2017-05-07 23:33:15 (646 KB/s) - ‘weather-stations20140101-20141231.csv’ saved [129821/129821]

# %% [markdown]
# ### 2- Load the dataset

# %%
import csv
import pandas as pd
import numpy as np

filename='weather-stations20140101-20141231.csv'

#Read csv
pdf = pd.read_csv(filename)
pdf.head(5)
# Out:
#                  Stn_Name     Lat     Long Prov   Tm  DwTm    D    Tx  DwTx  \
# 0               CHEMAINUS  48.935 -123.742   BC  8.2     0  NaN  13.5     0
# 1  COWICHAN LAKE FORESTRY  48.824 -124.133   BC  7.0     0  3.0  15.0     0
# 2           LAKE COWICHAN  48.829 -124.052   BC  6.8    13  2.8  16.0     9
# 3        DISCOVERY ISLAND  48.425 -123.226   BC  NaN   NaN  NaN  12.5     0
# 4     DUNCAN KELVIN CREEK  48.735 -123.728   BC  7.7     2  3.4  14.5     2
#
#     Tn   ...     DwP  P%N  S_G  Pd  BS  DwBS  BS%    HDD  CDD   Stn_No
# 0  1.0   ...       0  NaN    0  12 NaN   NaN  NaN  273.3    0  1011500
# 1 -3.0   ...       0  104    0  12 NaN   NaN  NaN  307.0    0  1012040
# 2 -2.5   ...       9  NaN  NaN  11 NaN   NaN  NaN  168.1    0  1012055
# 3  NaN   ...     NaN  NaN  NaN NaN NaN   NaN  NaN    NaN  NaN  1012475
# 4 -1.0   ...       2  NaN  NaN  11 NaN   NaN  NaN  267.7    0  1012573
#
# [5 rows x 25 columns]

# %% [markdown]
# ### 3-Cleaning

# %%
pdf=pdf[pd.notnull(pdf["Tm"])]
pdf = pdf.reset_index(drop=True)
pdf.head(5)
# Out:
#                  Stn_Name     Lat     Long Prov   Tm  DwTm    D    Tx  DwTx  \
# 0               CHEMAINUS  48.935 -123.742   BC  8.2     0  NaN  13.5     0
# 1  COWICHAN LAKE FORESTRY  48.824 -124.133   BC  7.0     0  3.0  15.0     0
# 2           LAKE COWICHAN  48.829 -124.052   BC  6.8    13  2.8  16.0     9
# 3     DUNCAN KELVIN CREEK  48.735 -123.728   BC  7.7     2  3.4  14.5     2
# 4       ESQUIMALT HARBOUR  48.432 -123.439   BC  8.8     0  NaN  13.1     0
#
#     Tn   ...     DwP  P%N  S_G  Pd  BS  DwBS  BS%    HDD  CDD   Stn_No
# 0  1.0   ...       0  NaN    0  12 NaN   NaN  NaN  273.3    0  1011500
# 1 -3.0   ...       0  104    0  12 NaN   NaN  NaN  307.0    0  1012040
# 2 -2.5   ...       9  NaN  NaN  11 NaN   NaN  NaN  168.1    0  1012055
# 3 -1.0   ...       2  NaN  NaN  11 NaN   NaN  NaN  267.7    0  1012573
# 4  1.9   ...       8  NaN  NaN  12 NaN   NaN  NaN  258.6    0  1012710
#
# [5 rows x 25 columns]

# %% [markdown]
# ### 4-Visualization

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
from pylab import rcParams
# %matplotlib inline
rcParams['figure.figsize'] = (14,10)

llon=-140
ulon=-50
llat=40
ulat=65

pdf = pdf[(pdf['Long'] > llon) & (pdf['Long'] < ulon) & (pdf['Lat'] > llat) &(pdf['Lat'] < ulat)]

my_map = Basemap(projection='merc',
            resolution = 'l', area_thresh = 1000.0,
            llcrnrlon=llon, llcrnrlat=llat, #min longitude (llcrnrlon) and latitude (llcrnrlat)
            urcrnrlon=ulon, urcrnrlat=ulat) #max longitude (urcrnrlon) and latitude (urcrnrlat)

my_map.drawcoastlines()
my_map.drawcountries()
my_map.drawmapboundary()
my_map.fillcontinents(color = 'white', alpha = 0.3)
my_map.shadedrelief()

# To collect data based on stations        

xs,ys = my_map(np.asarray(pdf.Long), np.asarray(pdf.Lat))
pdf['xm']= xs.tolist()
pdf['ym'] =ys.tolist()

#Visualization1
for index,row in pdf.iterrows():
#   x,y = my_map(row.Long, row.Lat)
   my_map.plot(row.xm, row.ym,markerfacecolor =([1,0,0]),  marker='o', markersize= 5, alpha = 0.75)
#plt.text(x,y,stn)
plt.show()

# %% [markdown]
# ### 5- Clustering of stations based on their location i.e. Lat & Lon

# %%
from sklearn.cluster import DBSCAN
import sklearn.utils
from sklearn.preprocessing import StandardScaler
sklearn.utils.check_random_state(1000)
Clus_dataSet = zip(np.asarray(pdf.xm),np.asarray(pdf.ym))
Clus_dataSet = np.nan_to_num(Clus_dataSet)
Clus_dataSet=StandardScaler().fit_transform(Clus_dataSet)

# Compute DBSCAN
db = DBSCAN(eps=0.15, min_samples=10).fit(Clus_dataSet)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_
pdf["Clus_Db"]=labels

realClusterNum=len(set(labels)) - (1 if -1 in labels else 0)
clusterNum = len(set(labels)) 


# A sample of clusters
pdf[["Stn_Name","Tx","Tm","Clus_Db"]].head(5)
# Out:
#                  Stn_Name    Tx   Tm  Clus_Db
# 0               CHEMAINUS  13.5  8.2        0
# 1  COWICHAN LAKE FORESTRY  15.0  7.0        0
# 2           LAKE COWICHAN  16.0  6.8        0
# 3     DUNCAN KELVIN CREEK  14.5  7.7        0
# 4       ESQUIMALT HARBOUR  13.1  8.8        0

# %% [markdown]
# ### 6- Visualization of clusters based on location

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
from pylab import rcParams
# %matplotlib inline
rcParams['figure.figsize'] = (14,10)

my_map = Basemap(projection='merc',
            resolution = 'l', area_thresh = 1000.0,
            llcrnrlon=llon, llcrnrlat=llat, #min longitude (llcrnrlon) and latitude (llcrnrlat)
            urcrnrlon=ulon, urcrnrlat=ulat) #max longitude (urcrnrlon) and latitude (urcrnrlat)

my_map.drawcoastlines()
my_map.drawcountries()
my_map.drawmapboundary()
my_map.fillcontinents(color = 'white', alpha = 0.3)
my_map.shadedrelief()

# To create a color map
colors = plt.get_cmap('jet')(np.linspace(0.0, 1.0, clusterNum))



#Visualization1
for index,row in pdf.iterrows():
    c=(([0.4,0.4,0.4]) if row.Clus_Db<0 else colors[np.float(row.Clus_Db)])
    my_map.plot(row.xm, row.ym,markerfacecolor =c,  marker='o', markersize= 5, alpha = 0.75)

for i in range(realClusterNum): 
    cluster=pdf[["Stn_Name","Tm","xm","ym","Clus_Db"]][pdf.Clus_Db==i]
    cenx=np.mean(cluster.xm) 
    ceny=np.mean(cluster.ym) 
    plt.text(cenx,ceny,str(i), fontsize=25, color='red',)
    print "Cluster "+str(i)+', Avg Temp: '+ str(np.mean(cluster.Tm))
# Out:
# /usr/local/src/bluemix_jupyter_bundle.v41/notebook/lib/python2.7/site-packages/ipykernel/__main__.py:25: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /usr/local/src/bluemix_jupyter_bundle.v41/notebook/lib/python2.7/site-packages/matplotlib/lines.py:1107: UnicodeWarning: Unicode unequal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if self._markerfacecolor != fc:
# Cluster 0, Avg Temp: -5.53874755382
# Cluster 1, Avg Temp: 1.95263157895
# Cluster 2, Avg Temp: -9.19565217391
# Cluster 3, Avg Temp: -15.3008333333
# Cluster 4, Avg Temp: -7.76904761905

# %% [markdown]
# ### 7- Clustering of stations based on their location and Temperature

# %%
from sklearn.cluster import DBSCAN
import sklearn.utils
from sklearn.preprocessing import StandardScaler
sklearn.utils.check_random_state(1000)
Clus_dataSet = zip(np.asarray(pdf.xm),np.asarray(pdf.ym),np.asarray(pdf.Tx),np.asarray(pdf.Tn),np.asarray(pdf.Tm))
Clus_dataSet = np.nan_to_num(Clus_dataSet)
Clus_dataSet=StandardScaler().fit_transform(Clus_dataSet)

# Compute DBSCAN
db = DBSCAN(eps=0.3, min_samples=10).fit(Clus_dataSet)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_
pdf["Clus_Db"]=labels

realClusterNum=len(set(labels)) - (1 if -1 in labels else 0)
clusterNum = len(set(labels)) 


# A sample of clusters
pdf[["Stn_Name","Tx","Tm","Clus_Db"]].head(5)
# Out:
#                  Stn_Name    Tx   Tm  Clus_Db
# 0               CHEMAINUS  13.5  8.2        0
# 1  COWICHAN LAKE FORESTRY  15.0  7.0        0
# 2           LAKE COWICHAN  16.0  6.8        0
# 3     DUNCAN KELVIN CREEK  14.5  7.7        0
# 4       ESQUIMALT HARBOUR  13.1  8.8        0

# %% [markdown]
# ### 8- Visualization of clusters based on location and Temperture

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
from pylab import rcParams
# %matplotlib inline
rcParams['figure.figsize'] = (14,10)

my_map = Basemap(projection='merc',
            resolution = 'l', area_thresh = 1000.0,
            llcrnrlon=llon, llcrnrlat=llat, #min longitude (llcrnrlon) and latitude (llcrnrlat)
            urcrnrlon=ulon, urcrnrlat=ulat) #max longitude (urcrnrlon) and latitude (urcrnrlat)

my_map.drawcoastlines()
my_map.drawcountries()
my_map.drawmapboundary()
my_map.fillcontinents(color = 'white', alpha = 0.3)
my_map.shadedrelief()

# To create a color map
colors = plt.get_cmap('jet')(np.linspace(0.0, 1.0, clusterNum))



#Visualization1
for index,row in pdf.iterrows():
    c=(([0.4,0.4,0.4]) if row.Clus_Db<0 else colors[np.float(row.Clus_Db)])
    my_map.plot(row.xm, row.ym,markerfacecolor =c,  marker='o', markersize= 5, alpha = 0.75)

for i in range(realClusterNum): 
    cluster=pdf[["Stn_Name","Tm","xm","ym","Clus_Db"]][pdf.Clus_Db==i]
    cenx=np.mean(cluster.xm) 
    ceny=np.mean(cluster.ym) 
    plt.text(cenx,ceny,str(i), fontsize=25, color='red',)
    print "Cluster "+str(i)+', Avg Temp: '+ str(np.mean(cluster.Tm))
# Out:
# /usr/local/src/bluemix_jupyter_bundle.v41/notebook/lib/python2.7/site-packages/ipykernel/__main__.py:25: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# Cluster 0, Avg Temp: 6.22119205298
# Cluster 1, Avg Temp: 6.79
# Cluster 2, Avg Temp: -0.494117647059
# Cluster 3, Avg Temp: -13.8772093023
# Cluster 4, Avg Temp: -4.1862745098
# Cluster 5, Avg Temp: -16.3015037594
# Cluster 6, Avg Temp: -13.6
# Cluster 7, Avg Temp: -9.75333333333
# Cluster 8, Avg Temp: -4.25833333333
